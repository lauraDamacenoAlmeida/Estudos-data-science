# %% [markdown]
# # Visualização dos loops
#
# Utilizando os dados gerados pelo notebook *loops_identifier* é criado dois gráficos para a visualização dos nodes que ocasionaram um maior número de loops.

# %% [markdown]
# ### Importação das bibliotecas necessárias

# %%
from IPython.display import display, Javascript, HTML
import json

# %% [markdown]
# ### Importação dos dados gerados pelo *loop_identifier*

# %%
import ibm_boto3
from ibm_botocore.client import Config, ClientError
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.

IAM_SERVICE_ID= 'iam-ServiceId-909bced8-39b7-4588-9a86-a22d5052679f',
IBM_API_KEY_ID= '8_aNG9dV_q-j9aTlBi97dSOCMQCvTo1ne8GOoAe3BDTA',
ENDPOINT= 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
IBM_AUTH_ENDPOINT= 'https://iam.bluemix.net/oidc/token',
BUCKET= 'bradesco-donotdelete-pr-9vaznqvkpmbjvh',
FILE= 'loops.json'

cos = ibm_boto3.resource("s3",
    ibm_api_key_id=IBM_API_KEY_ID,
    ibm_auth_endpoint=IBM_AUTH_ENDPOINT,
    config=Config(signature_version="oauth"),
    endpoint_url=ENDPOINT
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-40f5cbe035bb> in <module>()
#      16     ibm_auth_endpoint=IBM_AUTH_ENDPOINT,
#      17     config=Config(signature_version="oauth"),
# ---> 18     endpoint_url=ENDPOINT
#      19 )
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_boto3/__init__.py in resource(*args, **kwargs)
#      90     See :py:meth:`boto3.session.Session.resource`.
#      91     """
# ---> 92     return _get_default_session().resource(*args, **kwargs)
#      93
#      94
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibm_boto3/session.py in resource(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, ibm_api_key_id, ibm_service_instance_id, ibm_auth_endpoint, auth_function, token_manager, config)
# ...

# %%
data = [
[{'conversation_id': '3bffb54d-3cc5-48fe-91ac-478f390a95c2', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '3bffb54d-3cc5-48fe-91ac-478f390a95c2', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '3bffb54d-3cc5-48fe-91ac-478f390a95c2', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': 'cd9bc61b-208a-46f2-a89e-6b2cfb347e78', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'cd9bc61b-208a-46f2-a89e-6b2cfb347e78', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'cd9bc61b-208a-46f2-a89e-6b2cfb347e78', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': '2c2f7ed8-5abc-4922-9d24-1a08691ba4cf', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '2c2f7ed8-5abc-4922-9d24-1a08691ba4cf', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': 'e77ccf41-30c5-4c88-b6b1-95b389985ed2', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'e77ccf41-30c5-4c88-b6b1-95b389985ed2', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'e77ccf41-30c5-4c88-b6b1-95b389985ed2', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': '3534f786-3ed9-42ee-b35f-3e9e9043a24d', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '3534f786-3ed9-42ee-b35f-3e9e9043a24d', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '3534f786-3ed9-42ee-b35f-3e9e9043a24d', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': 'd594a709-0ad8-499f-b0d0-18d6a46f0d97', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'd594a709-0ad8-499f-b0d0-18d6a46f0d97', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'd594a709-0ad8-499f-b0d0-18d6a46f0d97', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': '79a9b5ba-a853-4daf-9c2c-7a67b77e906c', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '79a9b5ba-a853-4daf-9c2c-7a67b77e906c', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '79a9b5ba-a853-4daf-9c2c-7a67b77e906c', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': '99bd334c-600d-458f-b1f2-94f299010023', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '99bd334c-600d-458f-b1f2-94f299010023', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '99bd334c-600d-458f-b1f2-94f299010023', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': '19b5792e-1ed8-41cd-acf5-f7e816d47b38', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': '19b5792e-1ed8-41cd-acf5-f7e816d47b38', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id': 'ae14d85c-ca60-4701-b160-07a8f6985541', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'ae14d85c-ca60-4701-b160-07a8f6985541', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}, {'conversation_id': 'ae14d85c-ca60-4701-b160-07a8f6985541', 'node_id': 'n_1_54283b38-8964-11e9-8243-eeee0af461af', 'workspace_id': '64a80f00-6648-4621-b32d-247d51ffac69'}],
[{'conversation_id':
 'node_id': 'slot_4_1516362470658', 'workspace_id': '7f8b84e4-e1fa-4c5b-996c-2e55a7ce6d30'}],
[{'conversation_id': '41573a82-6c19-496c-bfe1-fca53596bfdb', 'node_id': 'slot_4_1516362470658', 'workspace_id': '7f8b84e4-e1fa-4c5b-996c-2e55a7ce6d30'}],
]

# %% [markdown]
# ### Formatação dos dados para um formato adequeado para a função de visualização

# %%
loops = dict()
loop_list = {}
workspaces = {}
workspaces_list = []

for conversation in data:
    nodes = {}
    workspace_id = conversation[0]['workspace_id']
    for i in range(len(conversation)):
        
        try:
            nodes[conversation[i]['node_id']] += 1
        except:
            nodes[conversation[i]['node_id']] = 1

    for node in nodes:
        try:
            loops[workspace_id][nodes[node]][node] += 1
        except:
            try:
                loops[workspace_id][nodes[node]][node] = 1
            except:
                try:
                    loops[workspace_id][nodes[node]] = {}
                    loops[workspace_id][nodes[node]][node] = 1
                except:
                    loops[workspace_id] = {}
                    loops[workspace_id][nodes[node]] = {}
                    loops[workspace_id][nodes[node]][node] = 1

# %%
for workspace in loops:
    loop_list[workspace] = {}
    workspaces[workspace] = 0
    for num in loops[workspace]:
        loop_list[workspace][num] = []
        for node in loops[workspace][num]:
            loop_list[workspace][num].append({'node_id': node, 'freq': loops[workspace][num][node]})
            workspaces[workspace] += loops[workspace][num][node]
            
for workspace in workspaces:
    workspaces_list.append({'workspace': workspace, 'loops': workspaces[workspace]})

# %% [markdown]
# ### Importação de bibliotecas Javascript para visualização

# %%
# %%javascript
# require.config({
#     paths: {
#         d3: 'https://d3js.org/d3.v5',
#         jquery: 'https://code.jquery.com/jquery-3.4.1.min'
#     }
# });

# %%
display(Javascript(url='https://raw.github.ibm.com/cbds-bradesco/bia-analytics/master/src/notebooks/js/loops.js?token=AAMwMW25YNa4i7WkdmOe3tuWeKGyLmOZks5dIMTQwA%3D%3D'))
display(HTML(url="https://raw.github.ibm.com/cbds-bradesco/bia-analytics/master/src/notebooks/js/loops.html?token=AAMwMVUOWOQf6KbPMSUgDrQhPOKevCNLks5dIMxFwA%3D%3D"))
# Out:
# <style>
#
#     @keyframes tool{
#         from {background: rgba(0, 0, 0, 0);}
#         to {background: rgba(0, 0, 0, 0.85);}
#     }
#     .select{
#       width: 50px
#     }
#     #chart-area {
#       font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
#       font-size: 24px;
#     }
#     .form-group {
#       font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
#       font-size: 16px;
#       display: in-line;
#     }
#     .d3-tip {
#       line-height: 1;
#       padding: 12px;
#       background: rgba(0, 0, 0, 0.85);
#       color: #fff;
#       border-radius: 2px;
#       pointer-events: none;
#       font-family: Helvetica, sans-serif;
#       text-align: center;
#       font-size: 12px;
#       box-shadow: 4px 4px 53px -8px rgba(0,0,0,0.8);
#       opacity: 0;
#       transition: opacity 0.4s;
#     }
#     /* Creates a small triangle extender for the tooltip */
#     .d3-tip:after {
#       box-sizing: border-box;
#       display: inline;
# ...

# %% [markdown]
# ### Função de visualização
#
# Dois gráficos são gerados: O de barras que representa em cada barra em *node_id* e o número de loops que ocorreram nesse node. No *input* "Núemro de loops" é possível filtrar pela quantidade de vezes que o usuário ficou "preso" no node.
#
# No gráfico de pizza, é possível visualizar a quantidade de loops para cada workspace e clicar nos mesmos para a sua visualização detalhada no gráfico de barras.

# %%
Javascript("""
(function(element){
    require(['loops'], function(loops) {
        loops(element.get(0), %s, %s)
    });
})(element);
""" % (json.dumps(loop_list), json.dumps(workspaces_list)))
